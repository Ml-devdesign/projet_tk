# %%
from tkinter import *

Tk(
    screenName=None, 
    baseName=None, 
    className='Tk', 
    useTk=1)
#base

# %%
import tkinter as tk

# Fonction appelée lorsque le bouton est cliqué
def on_button_click():
    label.config(text="Bonjour, Tkinter!")

# Créer la fenêtre principale
window = tk.Tk()
window.title("Exemple Tkinter")

# Créer un bouton
button = tk.Button(window, text="Cliquez-moi!", command=on_button_click)

# Créer une étiquette
label = tk.Label(window, text="Bienvenue dans Tkinter!")

# Organiser les widgets à l'intérieur de la fenêtre
label.pack(pady=10)
button.pack(pady=10)

# Lancer la boucle principale de l'application
window.mainloop()

#       Nous importons le module tkinter sous le nom tk.
#       Nous créons une fenêtre principale avec tk.Tk().
#       Nous définissons une fonction on_button_click qui sera appelée lorsque 
#       le bouton est cliqué.
#       Nous créons un bouton avec tk.Button et lui attribuons la fonction 
#       on_button_click à exécuter lorsqu'il est cliqué.
#       Nous créons une étiquette avec tk.Label pour afficher du texte.
#       Nous utilisons pack pour organiser les widgets dans la fenêtre.
#       Enfin, nous lançons la boucle principale avec window.mainloop().

#       Cet exemple est très basique, mais vous pouvez étendre et personnaliser 
#       l'interface utilisateur selon vos besoins en utilisant d'autres widgets 
#       disponibles dans Tkinter tels que les entrées, les listes, les cadres, etc. 
#       Explorez la documentation de Tkinter pour en savoir plus sur les fonctionnalités 
#       disponibles : Tkinter Documentation.

# %% [markdown]
# liste simple des étapes courantes pour créer une application Tkinter en Python :
#
# Importer Tkinter :
#
# import tkinter as tk
#
# Créer la fenêtre principale :
#
#
# window = tk.Tk()
#
# Ajouter des widgets (boutons, étiquettes, etc.) :
#
# label = tk.Label(window, text="Hello, Tkinter!")
# button = tk.Button(window, text="Click me!", command=on_button_click)
#
# Définir les fonctions associées aux widgets (par exemple, gestionnaires d'événements) :
#
# def on_button_click():
#     label.config(text="Button clicked!")
#
# Organiser les widgets à l'intérieur de la fenêtre (utilisation de gestionnaires de géométrie comme pack, grid ou place) :
#
# label.pack(pady=10)
# button.pack(pady=10)
#
# Lancer la boucle principale de l'application :
#
#     window.mainloop()
#
# Voici un exemple complet en utilisant ces étapes de base :
#
# import tkinter as tk
#
# def on_button_click():
#     label.config(text="Button clicked!")
#
# # Créer la fenêtre principale
# window = tk.Tk()
# window.title("Exemple Tkinter")
#
# # Ajouter des widgets
# label = tk.Label(window, text="Hello, Tkinter!")
# button = tk.Button(window, text="Click me!", command=on_button_click)
#
# # Organiser les widgets à l'intérieur de la fenêtre
# label.pack(pady=10)
# button.pack(pady=10)
#
# # Lancer la boucle principale de l'application
# window.mainloop()
#
# Cela crée une petite fenêtre Tkinter avec une étiquette et un bouton. Vous pouvez ensuite étendre cela en ajoutant d'autres widgets et fonctionnalités en fonction de vos besoins.
# User
#
# liste de widgets Tkinter couramment utilisés pour la création d'interfaces utilisateur :
#
# Label (Étiquette) :
#
# label = tk.Label(window, text="Hello, Tkinter!")
#
# Button (Bouton) :
#
# button = tk.Button(window, text="Click me!", command=on_button_click)
#
# Entry (Champ de saisie) :
#
# entry = tk.Entry(window)
#
# Text (Zone de texte) :
#
# text_widget = tk.Text(window)
#
# Frame (Cadre) :
#
# frame = tk.Frame(window)
#
# Canvas (Toile) :
#
# canvas = tk.Canvas(window, width=200, height=100)
#
# Checkbutton (Case à cocher) :
#
# check_button = tk.Checkbutton(window, text="Check me")
#
# Radiobutton (Bouton radio) :
#
# radio_button = tk.Radiobutton(window, text="Option 1", variable=var, value=1)
#
# Scale (Curseur) :
#
# scale = tk.Scale(window, from_=0, to=100, orient=tk.HORIZONTAL)
#
# Listbox (Boîte de liste) :
#
# listbox = tk.Listbox(window)
#
# Menu (Menu déroulant) :
#
# menu_bar = tk.Menu(window)
# file_menu = tk.Menu(menu_bar, tearoff=0)
# menu_bar.add_cascade(label="File", menu=file_menu)
#
# Scrollbar (Barre de défilement) :
#
# scrollbar = tk.Scrollbar(window)
# listbox = tk.Listbox(window, yscrollcommand=scrollbar.set)
# scrollbar.config(command=listbox.yview)
#
# LabelFrame (Cadre avec étiquette) :
#
# label_frame = tk.LabelFrame(window, text="My Frame")
#
# Message (Message) :
#
# message = tk.Message(window, text="This is a message.")
#
# Spinbox (Zone de saisie numérique) :
#
# spinbox = tk.Spinbox(window, from_=0, to=10)
#
# PanedWindow (Fenêtre divisée) :
#
# paned_window = tk.PanedWindow(window, orient=tk.HORIZONTAL)

# %%
import tkinter as tk

class Application(tk.Frame):
    def __init__(self, master=None):
        super().__init__(master)
        self.master = master
        self.pack()
        self.create_widgets()

    def create_widgets(self):
        self.hi_there = tk.Button(self)
        self.hi_there["text"] = "Hello World\n(click me)"
        self.hi_there["command"] = self.say_hi
        self.hi_there.pack(side="top")

        self.quit = tk.Button(self, text="QUIT", fg="red",
                              command=self.master.destroy)
        self.quit.pack(side="bottom")

    def say_hi(self):
        print("hi there, everyone!")

root = tk.Tk()
app = Application(master=root)
app.mainloop()
